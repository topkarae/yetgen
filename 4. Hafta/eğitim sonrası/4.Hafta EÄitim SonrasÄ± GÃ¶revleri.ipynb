# %% [markdown]
# # Problem 1
# `ogrenciler` adında bir sözlük oluşturunuz. Kullanıcıdan döngü yardımıyla 3 öğrenci için veri girmesini isteyerek öğrencilerin sırasıyla okul numarası, isim, soy isim, telefon numarası ve doğum tarihi bilgilerini alınız. Aldığınız öğrenci bilgilerini yine aynı döngü yardımıyla `ogrenciler` adındaki sözlükte saklayınız. Daha sonra öğrenci bilgilerinin bulunduğu sözlük yapısını ekrana bastırınız.

# %%
ogrenciler = {}

for i in range(1, 4):
    print(f"{i}. Öğrenci için bilgileri giriniz:")

    okul_no = input("Okul Numarası: ")
    isim = input("İsim: ")
    soy_isim = input("Soy İsim: ")
    telefon_no = input("Telefon Numarası: ")
    dogum_tarihi = input("Doğum Tarihi (GG/AA/YYYY): ")

    ogrenci_bilgileri = {
        "isim": isim,
        "soy_isim": soy_isim,
        "telefon_no": telefon_no,
        "dogum_tarihi": dogum_tarihi
    }

    ogrenciler[okul_no] = ogrenci_bilgileri

print("\nÖğrencilerin bilgileri:")
print(ogrenciler)
# Out:
# 1. Öğrenci için bilgileri giriniz:
# 2. Öğrenci için bilgileri giriniz:
# 3. Öğrenci için bilgileri giriniz:
#
# Öğrencilerin bilgileri:
# {'522': {'isim': 'Refik', 'soy_isim': 'Yılmaz', 'telefon_no': '0532 456 78 90', 'dogum_tarihi': '15/03/1990'}, '756': {'isim': 'Emine', 'soy_isim': 'Korkmaz', 'telefon_no': '0543 488 13 68', 'dogum_tarihi': '30/08/2000'}, '381': {'isim': 'Eslem', 'soy_isim': 'Konak', 'telefon_no': '0542 987 65 43', 'dogum_tarihi': '07/09/1997'}}

# %% [markdown]
# # Problem 2
#
# ### a - Biraz ısınarak başlayalım!
#
# ```
# numbers = [5,10,10,15,15,15,20,20,20,20]
# ```
#
# Yukarıda `numbers` adında 10 elemanlı bir liste verilmiştir. Bu listenin her elemanını kontrol eden ve tekrar eden elemanları bir kez olacak şekilde başka bir listeye kopyalayan bir program yazınız. Son olarak oluşturduğunuz listeyi ekrana bastırınız.
#
#
#
#
# ```
# >Output
# [5, 10, 15, 20]
# ```

# %%
numbers = [5, 10, 10, 15, 15, 15, 20, 20, 20, 20]

seen = set()

unique_numbers = []

for number in numbers:
    if number not in seen:
        unique_numbers.append(number)
        seen.add(number)

print(unique_numbers)
# Out:
# [5, 10, 15, 20]

# %% [markdown]
# ### 🌶️ b) Hadi işi biraz daha zorlaştıralım!
#
#
# Şimdiyse senden `numbers` isimli listedeki tekrar eden elemanları `repeatNumbers` adındaki listeye; tekrar etmeyen elemanları `uniqueNumbers`adındaki listeye kopyalayan yazmanı ve listeleri ekrana bastırmanı bekliyoruz
#
# ```
# >Output
# Tekrar Eden Elemanlar: [10, 10, 15, 15, 15, 20, 20, 20, 20]
# Tekrar Etmeyen Elemanlar: [5]
# ```

# %%
numbers = [5, 10, 10, 15, 15, 15, 20, 20, 20, 20]

count_dict = {}

for number in numbers:
    if number in count_dict:
        count_dict[number] += 1
    else:
        count_dict[number] = 1

repeatNumbers = []
uniqueNumbers = []

for number, count in count_dict.items():
    if count > 1:
        repeatNumbers.extend([number] * count)
    else:
        uniqueNumbers.append(number)

# Listeleri ekrana bastırıyoruz
print("Tekrar Eden Elemanlar:", repeatNumbers)
print("Tekrar Etmeyen Elemanlar:", uniqueNumbers)
# Out:
# Tekrar Eden Elemanlar: [10, 10, 15, 15, 15, 20, 20, 20, 20]
# Tekrar Etmeyen Elemanlar: [5]

# %% [markdown]
# # Problem 3
# sn1 = {1,2,3,4,5}
#
# sn2 = {4,5,6,7,8}
#
#  Verilen 2 adet küme için kesişimlerini, farklarını ve birleşimlerini bulunuz.

# %%
sn1 = {1, 2, 3, 4, 5}
sn2 = {4, 5, 6, 7, 8}

kesisim = sn1.intersection(sn2)

fark_sn1_sn2 = sn1.difference(sn2)
fark_sn2_sn1 = sn2.difference(sn1)

birlesim = sn1.union(sn2)

print("Kesişim:", kesisim)
print("sn1'in sn2'den farkı:", fark_sn1_sn2)
print("sn2'nin sn1'den farkı:", fark_sn2_sn1)
print("Birleşim:", birlesim)
# Out:
# Kesişim: {4, 5}
# sn1'in sn2'den farkı: {1, 2, 3}
# sn2'nin sn1'den farkı: {8, 6, 7}
# Birleşim: {1, 2, 3, 4, 5, 6, 7, 8}

# %% [markdown]
# # Problem 4
#
# Buradaki işlemlerimizin tamamı stringler içindir. Aşağıda verilecek olan metodlar için kendinizin örnek yaratması gerekmektedir.
#
# Örneğin `upper` için `string` değişkeni oluştururken` k = "BAC"` şeklinde oluşturmayınız. Bunun yerine k değişkenini `k = "bac`" şeklinde oluşturmanız `upper` metodundaki değişimi görebilmeniz için daha iyi olacaktır.
#
# Bütün metodlardaki değişimin gözle görülür şekilde değişimi beklenmektedir.
#
#
# 1- capitalize(), lower(), upper(), swapcase(), title(), replace()
#
# 2- endswith(), startswith(), find(), index(), count()
#
# 3- split(), strip(), join(), islower(), isalpha(), isdigit()
#
#
# Yukarıdaki `string` metodlarındaki değişimleri görebildiğimiz bir program yazınız.

# %%
k = "merhaba dünya, merhaba yetgenli!"

print("Orijinal:", k)
print("capitalize():", k.capitalize())
print("lower():", k.lower())         
print("upper():", k.upper())            
print("swapcase():", k.swapcase())    
print("title():", k.title())      
print("replace('merhaba', 'selam'):", k.replace('merhaba', 'selam'))  

print()

print("Orijinal:", k)
print("endswith('!'):", k.endswith('!'))          
print("startswith('merhaba'):", k.startswith('merhaba')) 
print("find('dünya'):", k.find('dünya'))          
print("index('dünya'):", k.index('dünya'))        
print("count('merhaba'):", k.count('merhaba'))     

print()

print("Orijinal:", k)
print("split() (default):", k.split())                    
print("split(','):", k.split(','))                        
print("strip() (default):", k.strip())                    
print("join(['Merhaba', 'Dünya']):", ' '.join(['Merhaba', 'Dünya'])) 
print("islower():", k.islower())                          
print("isalpha() ('merhaba'):", 'merhaba'.isalpha())       
print("isdigit() ('12345'):", '12345'.isdigit())
# Out:
# Orijinal: merhaba dünya, merhaba yetgenli!
# capitalize(): Merhaba dünya, merhaba yetgenli!
# lower(): merhaba dünya, merhaba yetgenli!
# upper(): MERHABA DÜNYA, MERHABA YETGENLI!
# swapcase(): MERHABA DÜNYA, MERHABA YETGENLI!
# title(): Merhaba Dünya, Merhaba Yetgenli!
# replace('merhaba', 'selam'): selam dünya, selam yetgenli!
#
# Orijinal: merhaba dünya, merhaba yetgenli!
# endswith('!'): True
# startswith('merhaba'): True
# find('dünya'): 8
# index('dünya'): 8
# count('merhaba'): 2
#
# Orijinal: merhaba dünya, merhaba yetgenli!
# split() (default): ['merhaba', 'dünya,', 'merhaba', 'yetgenli!']
# split(','): ['merhaba dünya', ' merhaba yetgenli!']
# strip() (default): merhaba dünya, merhaba yetgenli!
# join(['Merhaba', 'Dünya']): Merhaba Dünya
# islower(): True
# isalpha() ('merhaba'): True
# isdigit() ('12345'): True
